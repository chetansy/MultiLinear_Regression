# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
startup = pd.read_csv("C:\\Users\\Chetan Yewale\\Downloads\\50_Startups.csv")

# %%
startup.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
startup.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
startup.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
import seaborn as sns

# %%
sns.pairplot(startup.iloc[:,:])

# %%
startup.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
Startup= pd.get_dummies(startup['State'])

# %%
startup = pd.concat([startup,Startup],axis = 1)

# %%
startup = startup.drop(["State"],axis = 1)

# %%
import statsmodels.formula.api as smf

# %%
startup = startup.iloc[:,[3,0,1,2,4,5,6]]

# %%
startup
# Out:
#        Profit  R&D Spend  Administration  Marketing Spend  California  \
# 0   192261.83  165349.20       136897.80        471784.10           0
# 1   191792.06  162597.70       151377.59        443898.53           1
# 2   191050.39  153441.51       101145.55        407934.54           0
# 3   182901.99  144372.41       118671.85        383199.62           0
# 4   166187.94  142107.34        91391.77        366168.42           0
# 5   156991.12  131876.90        99814.71        362861.36           0
# 6   156122.51  134615.46       147198.87        127716.82           1
# 7   155752.60  130298.13       145530.06        323876.68           0
# 8   152211.77  120542.52       148718.95        311613.29           0
# 9   149759.96  123334.88       108679.17        304981.62           1
# 10  146121.95  101913.08       110594.11        229160.95           0
# 11  144259.40  100671.96        91790.61        249744.55           1
# 12  141585.52   93863.75       127320.38        249839.44           0
# 13  134307.35   91992.39       135495.07        252664.93           1
# 14  132602.65  119943.24       156547.42        256512.92           0
# 15  129917.04  114523.61       122616.84        261776.23           0
# 16  126992.93   78013.11       121597.55        264346.06           1
# 17  125370.37   94657.16       145077.58        282574.31           0
# 18  124266.90   91749.16       114175.79        294919.57           0
# 19  122776.86   86419.70       153514.11             0.00           0
# 20  118474.03   76253.86       113867.30        298664.47           1
# 21  111313.02   78389.47       153773.43        299737.29           0
# 22  110352.25   73994.56       122782.75        303319.26           0
# 23  108733.99   67532.53       105751.03        304768.73           0
# 24  108552.04   77044.01        99281.34        140574.81           0
# 25  107404.34   64664.71       139553.16        137962.62           1
# 26  105733.54   75328.87       144135.98        134050.07           0
# 27  105008.31   72107.60       127864.55        353183.81           0
# 28  103282.38   66051.52       182645.56        118148.20           0
# 29  101004.64   65605.48       153032.06        107138.38           0
# 30   99937.59   61994.48       115641.28         91131.24           0
# 31   97483.56   61136.38       152701.92         88218.23           0
# 32   97427.84   63408.86       129219.61         46085.25           1
# 33   96778.92   55493.95       103057.49        214634.81           0
# 34   96712.80   46426.07       157693.92        210797.67           1
# 35   96479.51   46014.02        85047.44        205517.64           0
# 36   90708.19   28663.76       127056.21        201126.82           0
# 37   89949.14   44069.95        51283.14        197029.42           1
# 38   81229.06   20229.59        65947.93        185265.10           0
# 39   81005.76   38558.51        82982.09        174999.30           1
# 40   78239.91   28754.33       118546.05        172795.67           1
# 41   77798.83   27892.92        84710.77        164470.71           0
# 42   71498.49   23640.93        96189.63        148001.11           1
# 43   69758.98   15505.73       127382.30         35534.17           0
# 44   65200.33   22177.74       154806.14         28334.72           1
# 45   64926.08    1000.23       124153.04          1903.93           0
# 46   49490.75    1315.46       115816.21        297114.46           0
# 47   42559.73       0.00       135426.92             0.00           1
# 48   35673.41     542.05        51743.15             0.00           0
# 49   14681.40       0.00       116983.80         45173.06           1
#
#     Florida  New York
# 0         0         1
# 1         0         0
# 2         1         0
# 3         0         1
# 4         1         0
# 5         0         1
# 6         0         0
# 7         1         0
# 8         0         1
# 9         0         0
# 10        1         0
# 11        0         0
# 12        1         0
# 13        0         0
# 14        1         0
# 15        0         1
# 16        0         0
# 17        0         1
# 18        1         0
# 19        0         1
# 20        0         0
# 21        0         1
# 22        1         0
# 23        1         0
# 24        0         1
# 25        0         0
# 26        1         0
# 27        0         1
# 28        1         0
# 29        0         1
# 30        1         0
# 31        0         1
# 32        0         0
# 33        1         0
# 34        0         0
# 35        0         1
# 36        1         0
# 37        0         0
# 38        0         1
# 39        0         0
# 40        0         0
# 41        1         0
# 42        0         0
# 43        0         1
# 44        0         0
# 45        0         1
# 46        1         0
# 47        0         0
# 48        0         1
# 49        0         0

# %%
import seaborn as sn

# %%
sn.pairplot(startup)

# %%
cor_values = startup.corr()

# %%
cor_values
# Out:
#                    Profit  R&D Spend  Administration  Marketing Spend  \
# Profit           1.000000   0.972900        0.200717         0.747766
# R&D Spend        0.972900   1.000000        0.241955         0.724248
# Administration   0.200717   0.241955        1.000000        -0.032154
# Marketing Spend  0.747766   0.724248       -0.032154         1.000000
# California      -0.145837  -0.143165       -0.015478        -0.168875
# Florida          0.116244   0.105711        0.010493         0.205685
# New York         0.031368   0.039068        0.005145        -0.033670
#
#                  California   Florida  New York
# Profit            -0.145837  0.116244  0.031368
# R&D Spend         -0.143165  0.105711  0.039068
# Administration    -0.015478  0.010493  0.005145
# Marketing Spend   -0.168875  0.205685 -0.033670
# California         1.000000 -0.492366 -0.515152
# Florida           -0.492366  1.000000 -0.492366
# New York          -0.515152 -0.492366  1.000000

# %%
from sklearn.model_selection import train_test_split

# %%
train_data,test_data = train_test_split(startup)

# %%
startup.rename(columns={'R&D Spend': 'RnD','Marketing Spend':'Marketing','New York':'NewYork'},inplace=True)

# %%
train_data.rename(columns={'R&D Spend': 'RnD','Marketing Spend':'Marketing','New York':'NewYork'},inplace=True)

# %%
test_data.rename(columns={'R&D Spend': 'RnD','Marketing Spend':'Marketing','New York':'NewYork'},inplace=True)

# %%
train_data.to_csv("train_data.csv",encoding="utf-8")

# %%
test_data.to_csv("test_data.csv",encoding="utf-8")

# %%
model_1= smf.ols("Profit~RnD+Administration+Marketing+California+Florida+NewYork",data=train_data).fit()

# %%
model_1.summary() ### adj R2 = 0.944
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Profit   R-squared:                       0.952
# Model:                            OLS   Adj. R-squared:                  0.944
# Method:                 Least Squares   F-statistic:                     123.4
# Date:                Wed, 06 Oct 2021   Prob (F-statistic):           1.66e-19
# Time:                        19:04:31   Log-Likelihood:                -388.08
# No. Observations:                  37   AIC:                             788.2
# Df Residuals:                      31   BIC:                             797.8
# Df Model:                           5
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       3.385e+04   6165.417      5.490      0.000    2.13e+04    4.64e+04
# RnD                0.8001      0.050     15.845      0.000       0.697       0.903
# Administration     0.0234      0.065      0.358      0.723      -0.110       0.157
# Marketing          0.0240      0.018      1.299      0.203      -0.014       0.062
# California      8199.7596   3139.298      2.612      0.014    1797.118    1.46e+04
# Florida         1.248e+04   3278.276      3.807      0.001    5795.541    1.92e+04
# NewYork         1.317e+04   2767.905      4.756      0.000    7519.826    1.88e+04
# ==============================================================================
# Omnibus:                       12.720   Durbin-Watson:                   2.305
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               15.312
# Skew:                          -0.994   Prob(JB):                     0.000473
# Kurtosis:                       5.446   Cond. No.                     1.51e+21
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.11e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """
